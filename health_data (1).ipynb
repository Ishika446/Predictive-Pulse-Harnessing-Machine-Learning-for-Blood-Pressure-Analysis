# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import numpy as np

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#       Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0                  1                           1                11.28
# 1                  2                           0                 9.75
# 2                  3                           1                10.79
# 3                  4                           0                11.00
# 4                  5                           1                14.17
# ...              ...                         ...                  ...
# 1995            1996                           1                10.14
# 1996            1997                           1                11.77
# 1997            1998                           1                16.91
# 1998            1999                           0                11.15
# 1999            2000                           1                11.36
#
#       Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# ...

# %%
main=["Blood_Pressure_Abnormality","Level_of_Hemoglobin","Genetic_Pedigree_Coefficient","Age","BMI","Sex","Pregnancy","Smoking","Physical_activity","salt_content_in_the_diet","alcohol_consumption_per_day","Level_of_Stress","Chronic_kidney_disease","Adrenal_and_thyroid_disorders"]

# %%
df_main=df[main]

# %%
df_main
# Out:
#       Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0                              1                11.28
# 1                              0                 9.75
# 2                              1                10.79
# 3                              0                11.00
# 4                              1                14.17
# ...                          ...                  ...
# 1995                           1                10.14
# 1996                           1                11.77
# 1997                           1                16.91
# 1998                           0                11.15
# 1999                           1                11.36
#
#       Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# 0                             0.90   34   23    1        1.0        0
# 1                             0.23   54   33    1        NaN        0
# 2                             0.91   70   49    0        NaN        0
# ...

# %%
df_main = df_main.fillna(0)

# %%
df_main
# Out:
#       Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0                              1                11.28
# 1                              0                 9.75
# 2                              1                10.79
# 3                              0                11.00
# 4                              1                14.17
# ...                          ...                  ...
# 1995                           1                10.14
# 1996                           1                11.77
# 1997                           1                16.91
# 1998                           0                11.15
# 1999                           1                11.36
#
#       Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# 0                             0.90   34   23    1        1.0        0
# 1                             0.23   54   33    1        0.0        0
# 2                             0.91   70   49    0        0.0        0
# ...

# %%
df_main['Pregnancy'] = df_main['Pregnancy'].astype(int)

# %%
df_main['alcohol_consumption_per_day'] = df_main['alcohol_consumption_per_day'].astype(int)

# %%
df_main
# Out:
#       Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0                              1                11.28
# 1                              0                 9.75
# 2                              1                10.79
# 3                              0                11.00
# 4                              1                14.17
# ...                          ...                  ...
# 1995                           1                10.14
# 1996                           1                11.77
# 1997                           1                16.91
# 1998                           0                11.15
# 1999                           1                11.36
#
#       Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# 0                             0.90   34   23    1          1        0
# 1                             0.23   54   33    1          0        0
# 2                             0.91   70   49    0          0        0
# ...

# %%
gender_counts = df['Sex'].value_counts()
plt.figure(figsize=(6,6))
new_label = ['Men', 'Women'] 
plt.pie(gender_counts, labels=new_label, autopct='%1.1f%%', startangle=90, colors=['#66b3ff','#ff9999'])
plt.title('Gender Distribution')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular
plt.show()
plt.savefig("pie_chart.png")

# %%
sns.countplot(x='Smoking', hue='Level_of_Stress', data=df)

plt.title('Count plot of Smoking by Level of Stress')
plt.xlabel('Smoking')
plt.ylabel('Count')
plt.legend(title='Level of Stress')
plt.show()
plt.savefig("smoking vs level of stress.png")

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Blood_Pressure_Abnormality     2000 non-null   int64
#  1   Level_of_Hemoglobin            2000 non-null   float64
#  2   Genetic_Pedigree_Coefficient   2000 non-null   float64
#  3   Age                            2000 non-null   int64
#  4   BMI                            2000 non-null   int64
#  5   Sex                            2000 non-null   int64
#  6   Pregnancy                      2000 non-null   int32
#  7   Smoking                        2000 non-null   int64
#  8   Physical_activity              2000 non-null   int64
#  9   salt_content_in_the_diet       2000 non-null   int64
#  10  alcohol_consumption_per_day    2000 non-null   int32
#  11  Level_of_Stress                2000 non-null   int64
# ...

# %%
label_encoder = LabelEncoder()
for col in main:
    df_main[col] = label_encoder.fit_transform(df[col])

# %%
df_main.head()
# Out:
#    Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0                           1                  296
# 1                           0                  146
# 2                           1                  248
# 3                           0                  269
# 4                           1                  553
#
#    Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# 0                            90   16   13    1          1        0
# 1                            23   36   23    1          2        0
# 2                            91   52   39    0          2        0
# 3                            43   53   40    0          2        0
# 4                            83   34    9    0          2        0
#
#    Physical_activity  salt_content_in_the_diet  alcohol_consumption_per_day  \
# 0               1798                      1880                          488
# 1               1006                       987                          199
# ...

# %%
select_col=['Age', 'Blood_Pressure_Abnormality', 'Level_of_Hemoglobin']
sns.pairplot(df_main[select_col])
plt.show()
plt.savefig("Multivariate analysis.png")

# %%
plt.hist(df['Age'], bins=20, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
plt.savefig("Univariate analysis.png")

# %%
df_main.("health.csv")
